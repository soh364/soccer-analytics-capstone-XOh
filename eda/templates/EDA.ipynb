# %% [markdown]
# # Complete Exploratory Data Analysis
#
# ## Georgia Tech MSA Spring 2026 Practicum

# %% [markdown]
# ## Purpose of This Notebook
#
# This notebook contains the complete, detailed exploratory data analysis of the StatsBomb dataset. It serves as:
#
# 1. **Technical Reference** - Full statistical analysis and validation
# 2. **Reproducibility Documentation** - All data processing steps documented
# 3. **Methodological Appendix** - Supporting evidence for claims in EDA_Executive.ipynb
#
# **Note:** This is a working document with verbose outputs. For the polished narrative, see **EDA_Executive.ipynb**.
#
# ---
